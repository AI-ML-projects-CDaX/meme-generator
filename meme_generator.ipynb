# %%
import random

memes = {
    "exam": [
        "When you studied everything except what came in the exam",
        "That moment when the question looks familiar but the answer doesn’t",
        "Me: I know this. Also me: I know nothing."
    ],
    "coding": [
        "It worked yesterday. I changed nothing.",
        "When your code runs but you don’t know why",
        "Debugging: fixing one bug and creating two more"
    ],
    "life": [
        "When life hits harder than expected",
        "That feeling when plans fail successfully",
        "Me pretending everything is fine"
    ]
}

print("Meme Categories: exam, coding, life")
choice = input("Choose a meme category: ").lower()

if choice in memes:
    caption = random.choice(memes[choice])
    print("\n😂 Meme Caption:")
    print(caption)
else:
    print("\n❌ Invalid category. Please try again.")
# Out:
# Meme Categories: exam, coding, life
# Choose a meme category:  exam
# 😂 Meme Caption:
# Me: I know this. Also me: I know nothing.
